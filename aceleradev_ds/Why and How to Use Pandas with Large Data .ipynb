# %%
import pandas as pd
import numpy as np

# %%
drinks = pd.read_csv('drinks_consumo.csv')
d = pd.read_csv('drinks_consumo.csv')

# %%
drinks.head(5)
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent consumo
# 0                           0.0  34.660.000      Asia     low
# 1                           4.9   2.876.000    Europe  middle
# 2                           0.7  40.061.000    Africa     low
# 3                          12.4  77.281.000    Europe    high
# 4                           5.9  28.081.000    Africa    high

# %% [markdown]
# # Selection a Single Column of Data
# - seleciona uma unica coluna como uma série

# %%
drinks['country']
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 188      Venezuela
# 189        Vietnam
# 190          Yemen
# 191         Zambia
# 192       Zimbabwe
# Name: country, Length: 193, dtype: object

# %% [markdown]
# # Selection with dot notation
# - outra forma

# %%
drinks.country
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 188      Venezuela
# 189        Vietnam
# 190          Yemen
# 191         Zambia
# 192       Zimbabwe
# Name: country, Length: 193, dtype: object

# %% [markdown]
# ## Problema com dot notation
# - Quando houver espaço nos nomes da coluna( ex: df.favorite food is wrong this way
# - Quando o nome da coluna é igual do métado do DataFrame
# - Quand o nome da coluna é uma variável

# %% [markdown]
# ## Nunca use o indexador ix (absoleto)
#
# - O indexador ix foi criado nos primeiros dias do Pandas para selecionar linhas e colunas por rótulo e local inteiro. Isso acabou sendo bastante ambíguo, pois os nomes de linhas e colunas do Pandas podem ser números inteiros e seqüências de caracteres.

# %% [markdown]
# ## Para fazer seleções explícitas, os indexadores iloc e loc foram disponibilizados
# - loc seleciona apenas por label
# - iloc seleciona apenas por local inteiro

# %% [markdown]
# ## Seleção com at e iat
# - seleciona uma unica cedula do dataframe
# - Eles fornecem uma ligeira vantagem de desempenho em relação aos indexadores análogos loc e iloc

# %% [markdown]
# # groupby aggregation

# %% [markdown]
# <b> - Grouping column </b>  Valores únicos formam grupos independentes
#
# <b> - Aggregation column </b> Colunas cujos os valores vão ser agregados. Geralmente numéricos
#
# <b> - Aggregation function </b> Como os valores serão agregados (soma,min,max,média etc)
#
# ### Sintaxes
# - há algumas sintaxes diferentes que o Pandas permite executar uma agregação por grupo.
# <b> Exemplo </b>
#
# <i> df.groupby('grouping column').agg({'aggregating column': 'aggregating function'})</i>

# %%
drinks.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol  population continent consumo
# 0                           0.0  34.660.000      Asia     low
# 1                           4.9   2.876.000    Europe  middle
# 2                           0.7  40.061.000    Africa     low
# 3                          12.4  77.281.000    Europe    high
# 4                           5.9  28.081.000    Africa    high

# %%
drinks.groupby('country').agg({'beer_servings':'max'}).head()
# Out:
#              beer_servings
# country
# Afghanistan              0
# Albania                 89
# Algeria                 25
# Andorra                245
# Angola                 217

# %% [markdown]
# # Sintaxe prefirida
#
# - Pode lidar com problemas de agrupamentos mais complexos
# - por exemplo se quisermos encontrar o máximo e o mínimo, juntamente com a média

# %%
drinks.groupby('country').agg({'beer_servings':['min','max'],
                              'wine_servings': ['min','max'],
                              'total_litres_of_pure_alcohol':'mean'})
# Out:
#             beer_servings      wine_servings      total_litres_of_pure_alcohol
#                       min  max           min  max                         mean
# country
# Afghanistan             0    0             0    0                          0.0
# Albania                89   89            54   54                          4.9
# Algeria                25   25            14   14                          0.7
# Andorra               245  245           312  312                         12.4
# Angola                217  217            45   45                          5.9
# ...                   ...  ...           ...  ...                          ...
# Venezuela             333  333             3    3                          7.7
# Vietnam               111  111             1    1                          2.0
# Yemen                   6    6             0    0                          0.1
# Zambia                 32   32             4    4                          2.5
# Zimbabwe               64   64             4    4                          4.7
#
# [193 rows x 5 columns]

# %% [markdown]
# # Guidance — Use
#
# df.groupby('grouping column').agg({'aggregating column': 'aggregating function'}) as your primary syntax of choice

# %% [markdown]
# # Manipulando um MultIndex
# - Um índice MultiIndex ou de vários níveis é uma adição complicada ao DataFrame do Pandas que ocasionalmente facilita a visualização dos dados, mas geralmente dificulta a manipulação. Você geralmente encontra um MultiIndex após uma chamada para o grupo ao usar várias colunas de agrupamento ou várias colunas de agregação.

# %%
agg_dict = {'beer_servings':['min','max'],
            'wine_servings': ['min','max'],
            'total_litres_of_pure_alcohol':'mean'}

drinks.groupby(['continent']).agg(agg_dict)
# Out:
#               beer_servings      wine_servings       \
#                         min  max           min  max
# continent
# Africa                    0  376             0  233
# Asia                      0  247             0  123
# Europe                    0  361             0  370
# North America             1  285             1  100
# Oceania                   0  306             0  212
# South America            93  333             1  221
#
#               total_litres_of_pure_alcohol
#                                       mean
# continent
# Africa                            3.007547
# Asia                              2.170455
# Europe                            8.617778
# North America                     5.995652
# Oceania                           3.381250
# South America                     6.308333

# %%
drinks
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan              0                0              0
# 1             1      Albania             89              132             54
# 2             2      Algeria             25                0             14
# 3             3      Andorra            245              138            312
# 4             4       Angola            217               57             45
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            333              100              3
# 189         189      Vietnam            111                2              1
# 190         190        Yemen              6                0              0
# 191         191       Zambia             32               19              4
# 192         192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol  population      continent consumo
# 0                             0.0  34.660.000           Asia     low
# 1                             4.9   2.876.000         Europe  middle
# 2                             0.7  40.061.000         Africa     low
# 3                            12.4  77.281.000         Europe    high
# 4                             5.9  28.081.000         Africa    high
# ..                            ...         ...            ...     ...
# 188                           7.7  30.620.404  South America    high
# 189                           2.0  93.448.000           Asia  middle
# 190                           0.1  27.058.000           Asia     low
# 191                           2.5  15.473.905         Africa     low
# 192                           4.7  13.061.239         Africa     low
#
# [193 rows x 9 columns]

# %%
drinks.groupby(['country','con']).agg({'total_litres_of_pure_alcohol':'mean'})
# Out:
#              total_litres_of_pure_alcohol
# country
# Afghanistan                           0.0
# Albania                               4.9
# Algeria                               0.7
# Andorra                              12.4
# Angola                                5.9
# ...                                   ...
# Venezuela                             7.7
# Vietnam                               2.0
# Yemen                                 0.1
# Zambia                                2.5
# Zimbabwe                              4.7
#
# [193 rows x 1 columns]

# %% [markdown]
# ### Vamos usar groupby para encontrar media de consumo por pais de vinho

# %%
d.groupby(['country','continent']).agg({'beer_servings':'mean'})
# Out:
#                            beer_servings
# country     continent
# Afghanistan Asia                       0
# Albania     Europe                    89
# Algeria     Africa                    25
# Andorra     Europe                   245
# Angola      Africa                   217
# ...                                  ...
# Venezuela   South America            333
# Vietnam     Asia                     111
# Yemen       Asia                       6
# Zambia      Africa                    32
# Zimbabwe    Africa                    64
#
# [193 rows x 1 columns]

# %% [markdown]
# ## Nos podemos duplicar os dados usando pivot_table

# %%
d.pivot_table(index='country',columns='continent', values='beer_servings',aggfunc='mean')
# Out:
# continent    Africa   Asia  Europe  North America  Oceania  South America
# country
# Afghanistan     NaN    0.0     NaN            NaN      NaN            NaN
# Albania         NaN    NaN    89.0            NaN      NaN            NaN
# Algeria        25.0    NaN     NaN            NaN      NaN            NaN
# Andorra         NaN    NaN   245.0            NaN      NaN            NaN
# Angola        217.0    NaN     NaN            NaN      NaN            NaN
# ...             ...    ...     ...            ...      ...            ...
# Venezuela       NaN    NaN     NaN            NaN      NaN          333.0
# Vietnam         NaN  111.0     NaN            NaN      NaN            NaN
# Yemen           NaN    6.0     NaN            NaN      NaN            NaN
# Zambia         32.0    NaN     NaN            NaN      NaN            NaN
# Zimbabwe       64.0    NaN     NaN            NaN      NaN            NaN
#
# [193 rows x 6 columns]

# %% [markdown]
# The <b>grouping column </b> são passado  parametros para o index e columns
# A <b> aggregation column</b> é passado parametros para valores
# <b>aggregating function</b> é passado parametro para aggfunc

# %%
Eu realmente gosto de usar pivot tables para comparar valores entre grupos e um groupby o quando eu quero continuar uma análise

# %% [markdown]
# ### A similaridade entre melt e stack os dois modelam os dados da mesma maneira
#
# - A maior diferença é que metado melt não trabalha com dados no index enquanto stack trabalha.

# %%
ad = pd.read_csv('IRIS.csv')

# %%
ad.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
ad.melt(id_vars='species', value_vars=['sepal_length','sepal_width','petal_width'])
# Out:
#             species      variable  value
# 0       Iris-setosa  sepal_length    5.1
# 1       Iris-setosa  sepal_length    4.9
# 2       Iris-setosa  sepal_length    4.7
# 3       Iris-setosa  sepal_length    4.6
# 4       Iris-setosa  sepal_length    5.0
# ..              ...           ...    ...
# 445  Iris-virginica   petal_width    2.3
# 446  Iris-virginica   petal_width    1.9
# 447  Iris-virginica   petal_width    2.0
# 448  Iris-virginica   petal_width    2.3
# 449  Iris-virginica   petal_width    1.8
#
# [450 rows x 3 columns]

# %%
df.nunique() #by typing this, we can see the counts of unique numbers in each column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-737e57af5071> in <module>
# ----> 1 df.nunique() #by typing this, we can see the counts of unique numbers in each column
#
# NameError: name 'df' is not defined
